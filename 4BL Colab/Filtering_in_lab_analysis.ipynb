# %% [markdown]
# Observations for visual low pass filtering setup:
#
# Point A connection. This setup causes an extremely fast flashing of the LED with a very bright flash when it's on. Hurts eyes to look at.
#
# Point B connection. While the flashing remains at a similar pace, the light itself is much dimmer.
#
# Point C connection. Light is steady, no blinking. It is also semi-dim as well.

# %%
import numpy as np

from google.colab import drive;
drive.mount('/content/drive');
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
Apass = np.loadtxt('/content/drive/My Drive/4BL/RC_FILT_A0.csv')
Bpass = np.loadtxt('/content/drive/My Drive/4BL/RC_FILT_B0.csv')
Cpass = np.loadtxt('/content/drive/My Drive/4BL/RC_FILT_C0.csv')

# %%
import matplotlib.pyplot as plt

# %%
Apass = Apass[2500:2800] / 10000;
plt.plot(Apass);

# %%
Bpass = Bpass[2500:2800] / 10000
plt.plot(Bpass)

# %%
Cpass = Cpass[2500:2800] / 10000
plt.plot(Cpass)

# %%
#time
time = np.arange(len(Apass)) / 4400

plt.plot(time, Apass)
plt.plot(time, Bpass)
plt.plot(time, Cpass)

# %%
#cutoff Frequency

R = 100
C = 0.001

R2 = 200
C2 = 0.002

freq = 1 / (2 * np.pi * R * C)
freq2 = 1 / (2 * np.pi * R2 * C2)


print(freq)
print(freq2)
# Out:
# 1.5915494309189535
# 0.3978873577297384
